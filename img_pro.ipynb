# %% [markdown]
# pillow
# - image load
# - image processing
#   - image resize
#   - image rotate
#   - image crop
#   - image flip
#   - image enhance
#   - image draw
# - image save

# %%
from PIL import Image, ImageDraw, ImageEnhance

# %%
im1_path = r"C:\Users\ZAID\Pictures\luffynaturo.jpg"
im2_path = r"C:\Users\ZAID\Pictures\girl_with_bag_in_forest.png"
im1 = Image.open(im1_path)
im2 = Image.open(im2_path)

# %%
print(im1)
print(im2)

# %%
im1.show() # in default image viewer

# %%
im2 # display in jupyter notebook

# %%
# load image from url
import requests
def load_image(url):
    return Image.open(requests.get(url, stream=True).raw)

# %%
url = 'https://th.bing.com/th/id/R.811a05c04dc2e6ddc23faa733e57ff79?rik=7sPTthQWn9ErzA&riu=http%3a%2f%2fwallsdesk.com%2fwp-content%2fuploads%2f2016%2f11%2fSpring-Photos.jpg&ehk=aPAKWQpFLEIXbOM90VXw8y8e9%2fT9Y4X609cUMdjGIc4%3d&risl=1&pid=ImgRaw&r=0'
im3 = load_image(url)
im3

# %%
url = 'https://images.hdqwalls.com/download/batman-commission-2t-3840x2160.jpg'
im4 = load_image(url)
im4

# %%
im4.save('img/batman.jpg')

# %%
im3.save("C:/Users/Zaid/Pictures/spring.jpg")

# %%
im3.transpose(Image.FLIP_TOP_BOTTOM)

# %%
print(im3.height, im3.width, im3.mode)

# %%
# size fixed
im3.resize((512, 512))

# %%
im1.rotate(45, fillcolor='white')

# %%
im2.rotate(90, expand=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=711x1076>
